# %%
import requests

# %%
url = "http://127.0.0.1:8888/"

response = requests.post(url)

print(response.status_code)
print(response.json())
# Out:
# 200
# {'message': 'APİ Aktf', 'status': 'True'}

# %%
import requests

url = "http://127.0.0.1:8888/subtitles"
files = {
    "file": open("../except/data/kesit.mp3", "rb")
}

data = {
    "language": "english",
    "chunk_length": 30,
}

response = requests.post(url, files=files,data=data)

print(response.status_code)
# Out:
# 200

# %%
response.content
# Out:
# b"1\r\n00:00:00,000 --> 00:00:16,760\r\nIt's been a long day without you, my friend\r\n\r\n2\r\n00:00:16,760 --> 00:00:22,739\r\nAnd I'll tell you all about it when I see you again\r\n\r\n3\r\n00:00:22,739 --> 00:00:28,820\r\nWe've come a long way from where we began\r\n\r\n4\r\n00:00:28,820 --> 00:00:29,980\r\nOh, I'll\r\n\r\n"

# %%
with open("temp.srt","wb") as file:
    file.write(response.content)

# %%
import os
os.chdir("../client")

# %%
import main
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import main
#
# File E:\PROJECT\GITHUB\GITHUB\audio_tosubtitles\client\main.py:2
#       1 import requests
# ----> 2 from tools import config,menu
#       4 class CLIENT:
#       5     def __init__(self):
#
# ImportError: cannot import name 'menu' from 'tools' (unknown location)

# %%
a={
    "a":1,
    "b":2
}

# %%
a["a"]=-1

# %%
a["c"]=1

# %%
a
# Out:
# {'a': -1, 'b': 2, 'c': 1}
